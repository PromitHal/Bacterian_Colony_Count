# %% [markdown]
# ![d.jpeg](attachment:67c064cd-ea51-4bdd-b464-6c3b0bd41de2.jpeg)

# %% [markdown]
# # **Segmentation of images obtained via Magnetic Resonance Imaging for the purpose of detecting presence of brain tumor**

# %%
Importing necessary dependancies

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
from glob import glob
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model ,Sequential
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D,MaxPooling2D, concatenate, Dense, Flatten, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

# %% [markdown]
# * * * Loading data

# %%
#Loading the black and white mask images
mask_files = glob('../input/lgg-mri-segmentation/kaggle_3m/*/*_mask*')
#Loading the brain images
image_files = [file.replace('_mask', '') for file in mask_files]

# %% [markdown]
# **Assembling MRI scans with the corresponding masks**

# %% [markdown]
# First of all, there can be two category of images,one with tumor detected via the mask and the other with no tumor detected.
# For MRI scans with a tumor detected, we are labeling them with 1,otherwise 0.

# %%
#Defining the function for labeling the masks
def mask_labelizer(mask_image):
    mask_image=cv2.imread(mask_image)
    label=np.max(mask_image)
    if(label>0):
        label=1
    else:
        label=0
    return label

# %%
#Assembling the MRI scans with their corresponding masks into a dataframe
MRI_DATA = pd.DataFrame(
    {              "images": image_files,
                   "masks": mask_files,
                   "label":[
                       mask_labelizer(mask) for mask in mask_files #Using List Apprehension
                   ]}
)
#Displaying the dataframe
MRI_DATA.head()
# Out:
#                                               images  \
# 0  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 1  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 2  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 3  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 4  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...
#
#                                                masks  label
# 0  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...      0
# 1  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...      0
# 2  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...      1
# 3  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...      1
# 4  ../input/lgg-mri-segmentation/kaggle_3m/TCGA_D...      1

# %%
#Verifying that correct labeling has taken place
MRI_DATA['label'].unique()
# Out:
# array([0, 1])

# %%
#Number of images
MRI_DATA.shape
# Out:
# (3929, 3)

# %% [markdown]
# **Looking at the MRI Scans with corresponding masks**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=[40,40])
for i in range(32):
   
    if(i%2==0):
        plt.subplot(8,4,i+1)        
        plt.title('MRI_Scan')
        plt.imshow(np.array(cv2.imread(MRI_DATA['images'].iloc[i])))
        
    else:
        plt.subplot(8,4,i+1)
        label=mask_labelizer(MRI_DATA['masks'].iloc[i])
        if(label==0):
                label='No Tumor'
        else:
                label='Tumor'
        plt.title(label)
        plt.imshow(np.array(cv2.imread(MRI_DATA['masks'].iloc[i])))

# %% [markdown]
# **Splitting data into training and testing**

# %%
from sklearn.model_selection import train_test_split
MRI_train,MRI_test=train_test_split(MRI_DATA,test_size=0.1,random_state=0)
MRI_test,MRI_val=train_test_split(MRI_test,test_size=0.5,random_state=0)
print('Shape of training data : {}\nShape of test data: {}\nShape of Validation data: {} '.format(len(MRI_train),len(MRI_test),len(MRI_val)))
# Out:
# Shape of training data : 3536
# Shape of test data: 196
# Shape of Validation data: 197

# %% [markdown]
# **Data Generator for Image Augmentation **
# This is an important step to prevent overfitting and providing our model exposure to a variety of images

# %%
'''Function for preprocessing images'''
#---------------------------------------------------------------------------------------------------------------------------------------------------------#
def preprocess_data(img,mask):
    img = img / 255.
    mask = mask / 255.
    #Converting Masks into black and white images
    mask[mask>0.5]=1
    mask[mask<=0.5]=0
    return (img, mask)
#---------------------------------------------------------------------------------------------------------------------------------------------------------#
'''Function for data augmentation'''
def image_augmentor(
       data_frame, batch_size,
        aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)#Data Generator for Images
    mask_datagen = ImageDataGenerator(**aug_dict) #Data Generator for Masks
    
   #----------------------------------------image augmentation for MRI scans-------------------------------------------------------------------------------
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "images",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)
   #-----------------------------------------------------image augmentation for masks-----------------------------------------------------------------------

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "masks",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)
  #--------------------------------------------------------------------------------------------------------------------------------------------------------
    train_augmentor = zip(image_generator, mask_generator)
    
    for (image, mask) in train_augmentor:
        image, mask = preprocess_data(image, mask)
        yield (image,mask)

# %% [markdown]
# # **Model Architecture**

# %% [markdown]
# For image segmentation tasks,widely used models are of "U-net" architecture. These models have an encoder unit(contracting unit) followed by a decoder unit(expansive unit). The two units are connected by a bridge layer.Image is downscaled in the contracting layer and upsclaed by the expansive layer

# %% [markdown]
# ![Res-U-Net-architecture-a-basic-block-of-the-Stack-U-Net-model-Another-possible-basic.png](attachment:42e15738-6962-4ad8-8189-c52d82830737.png)

# %% [markdown]
# **Building a "U-Net" Model**

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model


#---------------------------------------------------------------------------------------------------------------------------------------------------------#

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = Activation("relu")(x)
    x = Conv2D(num_filters, 3, padding="same")(x)
    x = Activation("relu")(x)
    return x

#---------------------------------------------------------------------------------------------------------------------------------------------------------#

'''Encoder or Contracting Block'''
def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

#---------------------------------------------------------------------------------------------------------------------------------------------------------#

'''Decoder or Expansive Block'''

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

#---------------------------------------------------------------------------------------------------------------------------------------------------------#

'''Connecting the enocder to decoder using bottleneck and skip connections'''

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model
#---------------------------------------------------------------------------------------------------------------------------------------------------------#
'''Loading our Model'''
input_shape = (256, 256, 3) #input shape of images is (256,256,3)
model = build_unet(input_shape)
model.summary()
# Out:
# 2022-02-06 03:33:50.184560: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:50.296149: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:50.296887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:50.297979: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-06 03:33:50.298921: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:50.299597: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:50.300243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:52.073424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:52.074220: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:52.074918: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-02-06 03:33:52.075532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 128 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 128 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 256)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      activation_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 512)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 1024) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  2097664     activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 512)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 512)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 256)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 256)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 128 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 128 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 256, 64) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 64) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  65          activation_17[0][0]
# ==================================================================================================
# Total params: 31,031,745
# Trainable params: 31,031,745
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
smooth=1.
#-----------------------------------------------------------------------------------------------------------------------------------------------------------#
'''Function for returning dice coefficient'''
def DICE_COEFF(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred)
    return (2.0 * intersection + smooth) / (union + smooth)
#-----------------------------------------------------------------------------------------------------------------------------------------------------------#

'''Dice Coefficient Loss'''
def dice_coef_loss(y_true, y_pred):
    return 1 - DICE_COEFF(y_true, y_pred)

#----------------------------------------------------------------------------------------------------------------------------------------------------------#
'''Function for combining binary cross entropy with dice coeffcients for loss function'''
def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    return dice_coef_loss(y_true, y_pred) + bce(y_true, y_pred)

#----------------------------------------------------------------------------------------------------------------------------------------------------------#

'''Function for Jacards coefficient'''
def IOU_JACARD(y_true, y_pred):
    y_true=K.flatten(y_true)
    y_pred=K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    sum_jac = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_jac - intersection + smooth)
    return jac

# %% [markdown]
# Parameters for training Model

# %%
EPOCHS = 100
BATCH_SIZE = 16
learning_rate = 1e-4

# %% [markdown]
# Setting up train generator and validation generator

# %%
train_generator_args = dict(rotation_range=0.1,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')

train_generator = image_augmentor(MRI_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(256,256))
    
validation_generator = image_augmentor(MRI_val, BATCH_SIZE,
                                dict(),
                                target_size=(256,256))

# %%
opt = Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, amsgrad=False)

callbacks = [ModelCheckpoint('MRI_Segment.hdf5', verbose=0, save_best_only=True),
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_lr=1e-11),
            EarlyStopping(monitor='val_loss', restore_best_weights=True, patience=12)]

# %%
model.compile(optimizer=opt, loss=bce_dice_loss, metrics=[IOU_JACARD, DICE_COEFF])

# %%
history = model.fit(train_generator,
                    steps_per_epoch=len(MRI_train) // 16, 
                    epochs=100, 
                    callbacks=callbacks,
                    validation_data = validation_generator,
                    validation_steps=len(MRI_val) // 16)
# Out:
# Found 3536 validated image filenames.
# Found 3536 validated image filenames.
# 2022-02-06 03:34:23.890566: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-02-06 03:34:26.211939: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 221/221 [==============================] - ETA: 0s - loss: 0.8785 - IOU_JACARD: 0.1587 - DICE_COEFF: 0.2430Found 197 validated image filenames.
# Found 197 validated image filenames.
# 221/221 [==============================] - 132s 536ms/step - loss: 0.8785 - IOU_JACARD: 0.1587 - DICE_COEFF: 0.2430 - val_loss: 0.6090 - val_IOU_JACARD: 0.3194 - val_DICE_COEFF: 0.4657
# Epoch 2/100
# 221/221 [==============================] - 97s 440ms/step - loss: 0.5469 - IOU_JACARD: 0.3601 - DICE_COEFF: 0.5056 - val_loss: 0.5533 - val_IOU_JACARD: 0.3509 - val_DICE_COEFF: 0.5000
# Epoch 3/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.4800 - IOU_JACARD: 0.4095 - DICE_COEFF: 0.5636 - val_loss: 0.5396 - val_IOU_JACARD: 0.3774 - val_DICE_COEFF: 0.5107
# Epoch 4/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.4579 - IOU_JACARD: 0.4335 - DICE_COEFF: 0.5854 - val_loss: 0.4848 - val_IOU_JACARD: 0.4106 - val_DICE_COEFF: 0.5519
# Epoch 5/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.4100 - IOU_JACARD: 0.4766 - DICE_COEFF: 0.6273 - val_loss: 0.4081 - val_IOU_JACARD: 0.4862 - val_DICE_COEFF: 0.6283
# Epoch 6/100
# 221/221 [==============================] - 97s 440ms/step - loss: 0.4150 - IOU_JACARD: 0.4725 - DICE_COEFF: 0.6218 - val_loss: 0.4182 - val_IOU_JACARD: 0.4705 - val_DICE_COEFF: 0.6100
# Epoch 7/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.3913 - IOU_JACARD: 0.4940 - DICE_COEFF: 0.6441 - val_loss: 0.3432 - val_IOU_JACARD: 0.5375 - val_DICE_COEFF: 0.6853
# Epoch 8/100
# 221/221 [==============================] - 99s 449ms/step - loss: 0.3594 - IOU_JACARD: 0.5263 - DICE_COEFF: 0.6729 - val_loss: 0.3358 - val_IOU_JACARD: 0.5497 - val_DICE_COEFF: 0.6941
# Epoch 9/100
# 221/221 [==============================] - 96s 437ms/step - loss: 0.3685 - IOU_JACARD: 0.5175 - DICE_COEFF: 0.6636 - val_loss: 0.2993 - val_IOU_JACARD: 0.5802 - val_DICE_COEFF: 0.7256
# Epoch 10/100
# 221/221 [==============================] - 96s 437ms/step - loss: 0.3512 - IOU_JACARD: 0.5357 - DICE_COEFF: 0.6808 - val_loss: 0.2944 - val_IOU_JACARD: 0.5874 - val_DICE_COEFF: 0.7310
# Epoch 11/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.3326 - IOU_JACARD: 0.5554 - DICE_COEFF: 0.6965 - val_loss: 0.3275 - val_IOU_JACARD: 0.5606 - val_DICE_COEFF: 0.7025
# Epoch 12/100
# 221/221 [==============================] - 97s 441ms/step - loss: 0.3234 - IOU_JACARD: 0.5671 - DICE_COEFF: 0.7054 - val_loss: 0.2494 - val_IOU_JACARD: 0.6440 - val_DICE_COEFF: 0.7754
# Epoch 13/100
# 221/221 [==============================] - 97s 437ms/step - loss: 0.3050 - IOU_JACARD: 0.5844 - DICE_COEFF: 0.7246 - val_loss: 0.2830 - val_IOU_JACARD: 0.6082 - val_DICE_COEFF: 0.7433
# Epoch 14/100
# 221/221 [==============================] - 96s 435ms/step - loss: 0.3098 - IOU_JACARD: 0.5781 - DICE_COEFF: 0.7181 - val_loss: 0.2581 - val_IOU_JACARD: 0.6342 - val_DICE_COEFF: 0.7652
# Epoch 15/100
# 221/221 [==============================] - 96s 434ms/step - loss: 0.3085 - IOU_JACARD: 0.5785 - DICE_COEFF: 0.7205 - val_loss: 0.3032 - val_IOU_JACARD: 0.5794 - val_DICE_COEFF: 0.7211
# Epoch 16/100
# 221/221 [==============================] - 96s 435ms/step - loss: 0.2999 - IOU_JACARD: 0.5882 - DICE_COEFF: 0.7281 - val_loss: 0.3883 - val_IOU_JACARD: 0.4974 - val_DICE_COEFF: 0.6514
# Epoch 17/100
# 221/221 [==============================] - 96s 437ms/step - loss: 0.2955 - IOU_JACARD: 0.5946 - DICE_COEFF: 0.7319 - val_loss: 0.2521 - val_IOU_JACARD: 0.6377 - val_DICE_COEFF: 0.7700
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 18/100
# 221/221 [==============================] - 96s 436ms/step - loss: 0.2581 - IOU_JACARD: 0.6354 - DICE_COEFF: 0.7642 - val_loss: 0.2440 - val_IOU_JACARD: 0.6530 - val_DICE_COEFF: 0.7783
# Epoch 19/100
# 221/221 [==============================] - 96s 437ms/step - loss: 0.2416 - IOU_JACARD: 0.6548 - DICE_COEFF: 0.7801 - val_loss: 0.2249 - val_IOU_JACARD: 0.6676 - val_DICE_COEFF: 0.7968
# Epoch 20/100
# 221/221 [==============================] - 96s 436ms/step - loss: 0.2485 - IOU_JACARD: 0.6505 - DICE_COEFF: 0.7727 - val_loss: 0.2191 - val_IOU_JACARD: 0.6755 - val_DICE_COEFF: 0.7997
# Epoch 21/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.2237 - IOU_JACARD: 0.6713 - DICE_COEFF: 0.7952 - val_loss: 0.2017 - val_IOU_JACARD: 0.6975 - val_DICE_COEFF: 0.8145
# Epoch 22/100
# 221/221 [==============================] - 97s 437ms/step - loss: 0.2174 - IOU_JACARD: 0.6824 - DICE_COEFF: 0.8006 - val_loss: 0.1979 - val_IOU_JACARD: 0.6959 - val_DICE_COEFF: 0.8176
# Epoch 23/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.2117 - IOU_JACARD: 0.6894 - DICE_COEFF: 0.8065 - val_loss: 0.1936 - val_IOU_JACARD: 0.7076 - val_DICE_COEFF: 0.8226
# Epoch 24/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.2172 - IOU_JACARD: 0.6831 - DICE_COEFF: 0.8006 - val_loss: 0.2292 - val_IOU_JACARD: 0.6603 - val_DICE_COEFF: 0.7928
# Epoch 25/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.2217 - IOU_JACARD: 0.6748 - DICE_COEFF: 0.7970 - val_loss: 0.1842 - val_IOU_JACARD: 0.7146 - val_DICE_COEFF: 0.8317
# Epoch 26/100
# 221/221 [==============================] - 96s 437ms/step - loss: 0.2014 - IOU_JACARD: 0.7002 - DICE_COEFF: 0.8159 - val_loss: 0.1899 - val_IOU_JACARD: 0.7075 - val_DICE_COEFF: 0.8248
# Epoch 27/100
# 221/221 [==============================] - 96s 436ms/step - loss: 0.1930 - IOU_JACARD: 0.7081 - DICE_COEFF: 0.8232 - val_loss: 0.1617 - val_IOU_JACARD: 0.7448 - val_DICE_COEFF: 0.8499
# Epoch 28/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.2038 - IOU_JACARD: 0.7015 - DICE_COEFF: 0.8122 - val_loss: 0.1606 - val_IOU_JACARD: 0.7472 - val_DICE_COEFF: 0.8528
# Epoch 29/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.1825 - IOU_JACARD: 0.7213 - DICE_COEFF: 0.8329 - val_loss: 0.1553 - val_IOU_JACARD: 0.7538 - val_DICE_COEFF: 0.8570
# Epoch 30/100
# 221/221 [==============================] - 97s 440ms/step - loss: 0.1804 - IOU_JACARD: 0.7263 - DICE_COEFF: 0.8346 - val_loss: 0.1562 - val_IOU_JACARD: 0.7512 - val_DICE_COEFF: 0.8551
# Epoch 31/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.1823 - IOU_JACARD: 0.7238 - DICE_COEFF: 0.8331 - val_loss: 0.1591 - val_IOU_JACARD: 0.7464 - val_DICE_COEFF: 0.8523
# Epoch 32/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.1690 - IOU_JACARD: 0.7397 - DICE_COEFF: 0.8454 - val_loss: 0.1461 - val_IOU_JACARD: 0.7648 - val_DICE_COEFF: 0.8651
# Epoch 33/100
# 221/221 [==============================] - 98s 442ms/step - loss: 0.1756 - IOU_JACARD: 0.7341 - DICE_COEFF: 0.8394 - val_loss: 0.1377 - val_IOU_JACARD: 0.7784 - val_DICE_COEFF: 0.8739
# Epoch 34/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.1672 - IOU_JACARD: 0.7418 - DICE_COEFF: 0.8471 - val_loss: 0.1340 - val_IOU_JACARD: 0.7826 - val_DICE_COEFF: 0.8769
# Epoch 35/100
# 221/221 [==============================] - 97s 437ms/step - loss: 0.1644 - IOU_JACARD: 0.7464 - DICE_COEFF: 0.8497 - val_loss: 0.1410 - val_IOU_JACARD: 0.7717 - val_DICE_COEFF: 0.8697
# Epoch 36/100
# 221/221 [==============================] - 96s 436ms/step - loss: 0.1686 - IOU_JACARD: 0.7430 - DICE_COEFF: 0.8456 - val_loss: 0.1318 - val_IOU_JACARD: 0.7849 - val_DICE_COEFF: 0.8784
# Epoch 37/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.1668 - IOU_JACARD: 0.7422 - DICE_COEFF: 0.8477 - val_loss: 0.1281 - val_IOU_JACARD: 0.7908 - val_DICE_COEFF: 0.8824
# Epoch 38/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.1710 - IOU_JACARD: 0.7377 - DICE_COEFF: 0.8431 - val_loss: 0.1311 - val_IOU_JACARD: 0.7863 - val_DICE_COEFF: 0.8795
# Epoch 39/100
# 221/221 [==============================] - 97s 438ms/step - loss: 0.1601 - IOU_JACARD: 0.7520 - DICE_COEFF: 0.8546 - val_loss: 0.1368 - val_IOU_JACARD: 0.7787 - val_DICE_COEFF: 0.8741
# Epoch 40/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.1592 - IOU_JACARD: 0.7529 - DICE_COEFF: 0.8543 - val_loss: 0.1515 - val_IOU_JACARD: 0.7571 - val_DICE_COEFF: 0.8597
# Epoch 41/100
# 221/221 [==============================] - 97s 437ms/step - loss: 0.1614 - IOU_JACARD: 0.7513 - DICE_COEFF: 0.8530 - val_loss: 0.1422 - val_IOU_JACARD: 0.7688 - val_DICE_COEFF: 0.8686
# Epoch 42/100
# 221/221 [==============================] - 97s 440ms/step - loss: 0.1606 - IOU_JACARD: 0.7509 - DICE_COEFF: 0.8530 - val_loss: 0.1196 - val_IOU_JACARD: 0.8029 - val_DICE_COEFF: 0.8902
# Epoch 43/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.1599 - IOU_JACARD: 0.7515 - DICE_COEFF: 0.8539 - val_loss: 0.1402 - val_IOU_JACARD: 0.7752 - val_DICE_COEFF: 0.8721
# Epoch 44/100
# 221/221 [==============================] - 97s 440ms/step - loss: 0.1618 - IOU_JACARD: 0.7516 - DICE_COEFF: 0.8518 - val_loss: 0.1389 - val_IOU_JACARD: 0.7764 - val_DICE_COEFF: 0.8715
# Epoch 45/100
# 221/221 [==============================] - 98s 442ms/step - loss: 0.1582 - IOU_JACARD: 0.7559 - DICE_COEFF: 0.8552 - val_loss: 0.1293 - val_IOU_JACARD: 0.7880 - val_DICE_COEFF: 0.8806
# Epoch 46/100
# 221/221 [==============================] - 99s 447ms/step - loss: 0.1471 - IOU_JACARD: 0.7687 - DICE_COEFF: 0.8660 - val_loss: 0.1234 - val_IOU_JACARD: 0.7970 - val_DICE_COEFF: 0.8861
# Epoch 47/100
# 221/221 [==============================] - 97s 441ms/step - loss: 0.8056 - IOU_JACARD: 0.1853 - DICE_COEFF: 0.2684 - val_loss: 0.7084 - val_IOU_JACARD: 0.1919 - val_DICE_COEFF: 0.3156
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 48/100
# 221/221 [==============================] - 98s 442ms/step - loss: 0.3017 - IOU_JACARD: 0.5725 - DICE_COEFF: 0.7096 - val_loss: 0.1575 - val_IOU_JACARD: 0.7404 - val_DICE_COEFF: 0.8498
# Epoch 49/100
# 221/221 [==============================] - 97s 440ms/step - loss: 0.1661 - IOU_JACARD: 0.7343 - DICE_COEFF: 0.8436 - val_loss: 0.1336 - val_IOU_JACARD: 0.7770 - val_DICE_COEFF: 0.8741
# Epoch 50/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.1597 - IOU_JACARD: 0.7466 - DICE_COEFF: 0.8505 - val_loss: 0.1353 - val_IOU_JACARD: 0.7762 - val_DICE_COEFF: 0.8727
# Epoch 51/100
# 221/221 [==============================] - 97s 440ms/step - loss: 0.1580 - IOU_JACARD: 0.7524 - DICE_COEFF: 0.8529 - val_loss: 0.1548 - val_IOU_JACARD: 0.7512 - val_DICE_COEFF: 0.8533
# Epoch 52/100
# 221/221 [==============================] - 97s 439ms/step - loss: 0.1497 - IOU_JACARD: 0.7616 - DICE_COEFF: 0.8616 - val_loss: 0.1756 - val_IOU_JACARD: 0.7450 - val_DICE_COEFF: 0.8331
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 53/100
# 221/221 [==============================] - 96s 437ms/step - loss: 0.1499 - IOU_JACARD: 0.7620 - DICE_COEFF: 0.8614 - val_loss: 0.1250 - val_IOU_JACARD: 0.7937 - val_DICE_COEFF: 0.8835
# Epoch 54/100
# 221/221 [==============================] - 97s 437ms/step - loss: 0.1525 - IOU_JACARD: 0.7592 - DICE_COEFF: 0.8591 - val_loss: 0.1255 - val_IOU_JACARD: 0.7925 - val_DICE_COEFF: 0.8832

# %%
model.save('Segmentation_MRI_BRAIN_A_Model.h5')

# %%
test_gen = image_augmentor(MRI_test, BATCH_SIZE,
                                dict(),
                                target_size=(256,256))
results = model.evaluate(test_gen, steps=len(MRI_test) / BATCH_SIZE)
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])

# %%
for i in range(50):
    index=np.random.randint(1,len(MRI_test.index))
    img = cv2.imread(MRI_test['images'].iloc[index])
    img = cv2.resize(img ,(256,256))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(MRI_test['masks'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()

# %%
MRI_test
